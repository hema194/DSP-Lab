# %%
import pandas as pd
a=pd.read_csv("1000 sales records.csv")
a
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
a.describe()
# Out:
#            Order ID   Units Sold  Unit Price    Unit Cost  Total Revenue  \
# count  1.000000e+03  1000.000000  1000.00000  1000.000000   1.000000e+03
# mean   5.496813e+08  5053.988000   262.10684   184.965110   1.327322e+06
# std    2.571334e+08  2901.375317   216.02106   175.289311   1.486515e+06
# min    1.029280e+08    13.000000     9.33000     6.920000   2.043250e+03
# 25%    3.280740e+08  2420.250000    81.73000    56.670000   2.811919e+05
# 50%    5.566097e+08  5184.000000   154.06000    97.440000   7.549392e+05
# 75%    7.696945e+08  7536.750000   421.89000   263.330000   1.733503e+06
# max    9.955298e+08  9998.000000   668.27000   524.960000   6.617210e+06
#
#          Total Cost  Total Profit
# count  1.000000e+03  1.000000e+03
# mean   9.361192e+05  3.912026e+05
# std    1.162571e+06  3.836402e+05
# min    1.416750e+03  5.326100e+02
# 25%    1.649319e+05  9.837612e+04
# 50%    4.647261e+05  2.772260e+05
# 75%    1.141750e+06  5.484568e+05
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
# Region            1000 non-null object
# Country           1000 non-null object
# Item Type         1000 non-null object
# Sales Channel     1000 non-null object
# Order Priority    1000 non-null object
# Order Date        1000 non-null object
# Order ID          1000 non-null int64
# Ship Date         1000 non-null object
# Units Sold        1000 non-null int64
# Unit Price        1000 non-null float64
# Unit Cost         1000 non-null float64
# Total Revenue     1000 non-null float64
# Total Cost        1000 non-null float64
# Total Profit      1000 non-null float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 109.5+ KB

# %%
a.head()
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
a.head(10)
# Out:
#                               Region     Country   Item Type Sales Channel  \
# 0       Middle East and North Africa       Libya   Cosmetics       Offline
# 1                      North America      Canada  Vegetables        Online
# 2       Middle East and North Africa       Libya   Baby Food       Offline
# 3                               Asia       Japan      Cereal       Offline
# 4                 Sub-Saharan Africa        Chad      Fruits       Offline
# 5                             Europe     Armenia      Cereal        Online
# 6                 Sub-Saharan Africa     Eritrea      Cereal        Online
# 7                             Europe  Montenegro     Clothes       Offline
# 8  Central America and the Caribbean     Jamaica  Vegetables        Online
# 9              Australia and Oceania        Fiji  Vegetables       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# ...

# %%
a.tail()
# Out:
#                            Region               Country   Item Type  \
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 995       Offline              C  4/18/2010  534085166  4/25/2010        6524
# 996       Offline              H   8/1/2011  590768182   9/7/2011         288
# 997        Online              C  5/12/2011  524363124  6/28/2011        9556
# 998       Offline              L  1/25/2016  289606320  2/14/2016        9801
# 999       Offline              C  4/10/2014  811546599   5/8/2014        3528
#
#      Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
a.tail(10)
# Out:
#                            Region               Country   Item Type  \
# 990            Sub-Saharan Africa                  Mali   Beverages
# 991            Sub-Saharan Africa               Liberia      Cereal
# 992                        Europe           Switzerland   Beverages
# 993         Australia and Oceania                Samoa    Baby Food
# 994                          Asia                 Nepal        Meat
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID  Ship Date  \
# 990        Online              L   3/17/2012  410452497  3/26/2012
# 991       Offline              H  12/17/2015  642683303  1/20/2016
# ...

# %%
a["Country"]
# Out:
# 0                     Libya
# 1                    Canada
# 2                     Libya
# 3                     Japan
# 4                      Chad
#                ...
# 995              Azerbaijan
# 996                 Georgia
# 997    United Arab Emirates
# 998                 Finland
# 999                Portugal
# Name: Country, Length: 1000, dtype: object

# %%
a[["Country","Order ID"]]
# Out:
#                   Country   Order ID
# 0                   Libya  686800706
# 1                  Canada  185941302
# 2                   Libya  246222341
# 3                   Japan  161442649
# 4                    Chad  645713555
# ..                    ...        ...
# 995            Azerbaijan  534085166
# 996               Georgia  590768182
# 997  United Arab Emirates  524363124
# 998               Finland  289606320
# 999              Portugal  811546599
#
# [1000 rows x 2 columns]

# %%
a[["Country","Order ID","Region"]]
# Out:
#                   Country   Order ID                        Region
# 0                   Libya  686800706  Middle East and North Africa
# 1                  Canada  185941302                 North America
# 2                   Libya  246222341  Middle East and North Africa
# 3                   Japan  161442649                          Asia
# 4                    Chad  645713555            Sub-Saharan Africa
# ..                    ...        ...                           ...
# 995            Azerbaijan  534085166  Middle East and North Africa
# 996               Georgia  590768182                        Europe
# 997  United Arab Emirates  524363124  Middle East and North Africa
# 998               Finland  289606320                        Europe
# 999              Portugal  811546599                        Europe
#
# [1000 rows x 3 columns]

# %%
a["Total Profit"].max()
# Out:
# 1726181.36

# %%
a["Total Profit"].min()
# Out:
# 532.61

# %%
a["Total Profit"]>6000
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 995    True
# 996    True
# 997    True
# 998    True
# 999    True
# Name: Total Profit, Length: 1000, dtype: bool

# %%
a[a["Total Profit"]>600000]
# Out:
#                                 Region               Country        Item Type  \
# 0         Middle East and North Africa                 Libya        Cosmetics
# 5                               Europe               Armenia           Cereal
# 13                  Sub-Saharan Africa                 Sudan        Cosmetics
# 19                  Sub-Saharan Africa               Senegal        Household
# 31   Central America and the Caribbean              Honduras  Office Supplies
# ..                                 ...                   ...              ...
# 987              Australia and Oceania                 Palau        Household
# 989              Australia and Oceania                  Fiji           Cereal
# 993              Australia and Oceania                Samoa         Baby Food
# 997       Middle East and North Africa  United Arab Emirates       Vegetables
# 998                             Europe               Finland        Household
#
# ...

# %%
a.loc[10]
# Out:
# Region            Sub-Saharan Africa
# Country                         Togo
# Item Type                    Clothes
# Sales Channel                 Online
# Order Priority                     M
# Order Date                12/29/2015
# Order ID                   451010930
# Ship Date                  1/19/2016
# Units Sold                      3012
# Unit Price                    109.28
# Unit Cost                      35.84
# Total Revenue                 329151
# Total Cost                    107950
# Total Profit                  221201
# Name: 10, dtype: object

# %%
a.loc[a["Total Profit"]>1000]
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
a["Address"]=0

# %%
import pandas as pd
a=pd.read_csv("1000 sales records.csv")

# %%
a.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
import pandas as pd
a=pd.read_csv('Emp_data.csv')
print(a)
# Out:
#        Name  Age  salary Gender  profit
# 0      Hema   19     100      M      10
# 1   Keerthi   18     200      F      20
# 2   Neeraja   18      30      M      15
# 3     Kittu   19     400      F      30
# 4   Haseena   18      50      M      20
# 5  Jyothsna   17       6      F     100
# 6     Divya   16      70      M      35
# 7  Likhitha   20      80      F      25
# 8   Lakshmi   21       9      M      15
# 9      Maha   33      10      F      50

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
xpoints=a["Name"].tolist()
ypoints=a["salary"].tolist()
plt.xlabel("Names of students")
plt.ylabel("Salary")
plt.title("Salary of each student")
plt.plot(xpoints,ypoints,marker="s",linewidth=3,mec="red",color="blue")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
xpoints=a["Name"].tolist()
ypoints=a["salary"].tolist()
zpoints=a["Age"].tolist()
apoints=a["profit"].tolist()
plt.plot(xpoints,ypoints,marker="s",linewidth=3,mec="red",color="blue")
plt.plot(xpoints,zpoints,marker="o",linewidth=2,mec="red",color="green")
plt.plot(xpoints,apoints,marker="*",linewidth=3,mec="red",color="orange")
plt.show()

# %%
b=pd.read_csv('1000 sales records.csv')
b
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
pointx=np.random.rand(40)
pointy=np.random.rand(40)
pointz=np.random.rand(40)
plt.scatter(pointz,pointy,pointz,s=pointz*100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-3b6c6ce3bae3> in <module>
#       4 pointy=np.random.rand(40)
#       5 pointz=np.random.rand(40)
# ----> 6 plt.scatter(pointz,pointy,pointz,s=pointz*100)
#       7 plt.show()
#
# TypeError: scatter() got multiple values for argument 's'
